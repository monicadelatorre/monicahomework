# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
from splinter import Browser
import time
import os
from sqlalchemy import create_engine

# %%
# # executable_path = {'executable_path': 'C:\\Users\\Gogster\\Desktop\\Drivers\\chromedriver.exe'}
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# # ZIKA Information 2017

# %%
urlzika = 'https://www.cdc.gov/zika/reporting/2017-case-counts.html'
browser.visit(urlzika)
htmlzika=browser.html

# %%
# browser.visit(url)
zika_soup = bs(browser.html, 'lxml')
# print(zika_soup.prettify())
time.sleep(2)

# %%
#scrape table
table_zika= pd.read_html(urlzika)
   #format
df_zika = table_zika[0]
# df_zika.columns = ['State', 'Count(w/symptoms)', "%", 'Count(w/o symptoms)','%']

# %%
df_zika.columns = ['State', 'Count_symptoms', "%", 'Count_no_symptoms','%']

# %%
#removed rows with labeling, not data was deleted
df_zika = df_zika.drop(df_zika.index[[54,55,0,1,2]])

# %%
# df_zika

# %%
# make a copy and manupilate the copy
new_zika_df = df_zika[['State', 'Count_symptoms','Count_no_symptoms']].copy()
# new_zika_df['yr'] = new_zika_df(numeric_only=True, axis=1)
new_zika_df['yr']= '2017'
# new_zika_df.head()
# new_zika_df.index.set_levels(['State'], level=0, inplace=True)
new_zika_df.rename(index={'id':'State'})
# Out:
#                    State Count_symptoms Count_no_symptoms    yr
# 3                Alabama              3                 4  2017
# 4                 Alaska              2                 0  2017
# 5                Arizona              3                 0  2017
# 6               Arkansas              0                 0  2017
# 7             California             49                 4  2017
# 8               Colorado              6                 0  2017
# 9            Connecticut              8                 0  2017
# 10              Delaware              0                 0  2017
# 11  District of Columbia              3                 0  2017
# 12              Florida‡            110                 5  2017
# 13               Georgia              2                 5  2017
# 14                Hawaii              6                 1  2017
# 15                 Idaho              0                 0  2017
# 16              Illinois              7                 0  2017
# ...

# %%
# df.loc[df[col name]==value]
# table[table.column_name == some val]

# %%
# new_zika_df.loc[new_zika_df['State']=='California']
# new_zika_df.loc[new_zika_df['State']=='Oregon']
# new_zika_df.loc[new_zika_df['State']=='Washington']
# new_zika_df[new_zika_df.State == 'California']
# new_zika_df.loc[[7,50,25]]
# new_zika_df

# %%
# state_list=["Oregon","California","Washington"]

# %%
# appended_data = []

# %%
# for states in state_list:
#     data = new_zika_df.loc[new_zika_df['State']==states]
#     appended_data.append(data)

# %% [markdown]
# # Zika 2016

# %%
urlz2016 = 'https://www.cdc.gov/zika/reporting/2016-case-counts.html'
browser.visit(urlz2016)
htmlzika=browser.html

# %%
# browser.visit(url)
zika2016_soup = bs(browser.html, 'lxml')
# print(zika_soup.prettify())
time.sleep(2)

# %%
#scrape table
table_zika_2016= pd.read_html(urlz2016)
   #format
df_zika_2016 = table_zika_2016[0]
# df_zika.columns = ['State', 'Count(w/symptoms)', "%", 'Count(w/o symptoms)','%']

# %%
df_zika_2016.columns = ['State', 'Count_symptoms', "%", 'Count_no_symptoms','%']

# %%
#removed rows with labeling, not data was deleted
df_zika_2016 = df_zika_2016.drop(df_zika_2016.index[[0,1,2,53,54]])

# %%
# make a copy and manupilate the copy
new_zika2016_df = df_zika_2016[['State', 'Count_symptoms','Count_no_symptoms']].copy()
# new_zika2016_df['yr'] = new_zika2016_df.mean(numeric_only=True, axis=1)
new_zika2016_df['yr']= '2016'
new_zika2016_df.rename(index={'id':'State'})
# new_zika2016_df.head()
# new_zika2016_df
# Out:
#                    State Count_symptoms Count_no_symptoms    yr
# 3                Alabama             37                 1  2016
# 4                Arizona             54                 1  2016
# 5               Arkansas             13                 0  2016
# 6             California            421                 4  2016
# 7               Colorado             55                 0  2016
# 8            Connecticut            118                 0  2016
# 9               Delaware             17                 0  2016
# 10  District of Columbia             41                 0  2016
# 11              Florida‡           1107                23  2016
# 12               Georgia            107                 0  2016
# 13                Hawaii             11                 0  2016
# 14                 Idaho              5                 0  2016
# 15              Illinois            105                 0  2016
# 16               Indiana             49                 0  2016
# ...

# %%
# new_zika2016_df.loc[new_zika2016_df['State']=='Oregon']

# %%
# for states in state_list:
#     data = new_zika2016_df.loc[new_zika2016_df['State']==states]
#     appended_data.append(data)

# %% [markdown]
# # Zika 2015

# %%
urlz2015 = 'https://www.cdc.gov/zika/reporting/2015-case-counts.html'
browser.visit(urlz2015)
htmlzika=browser.html

# %%
# browser.visit(url)
zika2015_soup = bs(browser.html, 'lxml')
# print(zika_soup.prettify())
time.sleep(2)

# %%
#scrape table
table_zika_2015= pd.read_html(urlz2015)
   #format
df_zika_2015 = table_zika_2015[0]
# df_zika.columns = ['State', 'Count(w/symptoms)', "%", 'Count(w/o symptoms)','%']

# %%
df_zika_2015.columns = ['State', 'Count_symptoms', "%", 'Count_no_symptoms','%']

# %%
#removed rows with labeling, not data was deleted
df_zika_2015 = df_zika_2015.drop(df_zika_2015.index[[0,1,2,53,54]])

# %%
# make a copy and manupilate the copy
new_zika2015_df = df_zika_2015[['State', 'Count_symptoms','Count_no_symptoms']].copy()
# new_zika2015_df['yr'] = new_zika2015_df.mean(numeric_only=True, axis=1)
new_zika2015_df['yr']='2015'
new_zika2015_df.rename(index={'id':'State'})
# new_zika2015_df.head()
# new_zika2015_df
# Out:
#                    State Count_symptoms Count_no_symptoms    yr
# 3                Alabama              0                 0  2015
# 4                Arizona              0                 0  2015
# 5               Arkansas              2                 0  2015
# 6             California             13                 0  2015
# 7               Colorado              0                 0  2015
# 8            Connecticut              0                 0  2015
# 9               Delaware              0                 0  2015
# 10  District of Columbia              4                 0  2015
# 11               Florida              6                 0  2015
# 12               Georgia              1                 0  2015
# 13                Hawaii              4                 0  2015
# 14                 Idaho              0                 0  2015
# 15              Illinois              0                 0  2015
# 16               Indiana              1                 0  2015
# ...

# %%
# state_list=["Oregon","California","Washington"]

# %%
# new_zika2015_df.loc[new_zika2015_df['State']=='Washington']

# %%
# for states in state_list:
#     data = new_zika2015_df.loc[new_zika2015_df['State']==states]
#     appended_data.append(data)

# %% [markdown]
# # FINAL EXTRACTION and Cleaning

# %%
newdf15=new_zika2015_df[new_zika2015_df['State'].isin(['California', 'Oregon', 'Washington'])].reset_index(drop=True)
newdf15.reset_index(level=0, inplace=True)
newdf15 = newdf15.rename(index=str, columns={"index": "id"})
newdf15
# Out:
#    id       State Count_symptoms Count_no_symptoms    yr
# 0   0  California             13                 0  2015
# 1   1      Oregon              0                 0  2015
# 2   2  Washington              0                 0  2015

# %%
newdf16=new_zika2016_df[new_zika2016_df['State'].isin(['California', 'Oregon', 'Washington'])].reset_index(drop=True)
newdf16.reset_index(level=0, inplace=True)
newdf16 = newdf16.rename(index=str, columns={"index": "id"})
newdf16
# Out:
#    id       State Count_symptoms Count_no_symptoms    yr
# 0   0  California            421                 4  2016
# 1   1      Oregon             47                 0  2016
# 2   2  Washington             69                 0  2016

# %%
newdf17=new_zika_df[new_zika_df['State'].isin(['California', 'Oregon', 'Washington'])].reset_index(drop=True)
newdf17.reset_index(level=0, inplace=True)
newdf17 = newdf17.rename(index=str, columns={"index": "id"})
newdf17
# Out:
#    id       State Count_symptoms Count_no_symptoms    yr
# 0   0  California             49                 4  2017
# 1   1      Oregon              5                 0  2017
# 2   2  Washington             15                 1  2017

# %% [markdown]
# # Connect to local database

# %%
#connect to local database
rds_connection_string = "root:password@127.0.0.1/weather_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %% [markdown]
# # Check for tables

# %%
engine.table_names()
# Out:
# ['ca_sqlresults', 'or_sqlresults', 'wa_sqlresults']

# %% [markdown]
# # Use pandas to load csv converted DataFrame into database

# %%
newdf15.to_sql(name='newdf15_sql', con=engine, if_exists='append', index=False)
newdf16.to_sql(name='newdf16_sql', con=engine, if_exists='append', index=False)
newdf17.to_sql(name='newdf17_sql', con=engine, if_exists='append', index=False)

# %% [markdown]
# # Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('SELECT * FROM newdf15_sql', con=engine)
# Out:
#    id       State Count_symptoms Count_no_symptoms    yr
# 0   0  California             13                 0  2015
# 1   1      Oregon              0                 0  2015
# 2   2  Washington              0                 0  2015

# %%
pd.read_sql_query('SELECT * FROM newdf16_sql', con=engine)
# Out:
#    id       State Count_symptoms Count_no_symptoms    yr
# 0   0  California            421                 4  2016
# 1   1      Oregon             47                 0  2016
# 2   2  Washington             69                 0  2016

# %%
pd.read_sql_query('SELECT * FROM newdf17_sql', con=engine)
# Out:
#    id       State Count_symptoms Count_no_symptoms    yr
# 0   0  California             49                 4  2017
# 1   1      Oregon              5                 0  2017
# 2   2  Washington             15                 1  2017

# %% [markdown]
# # Analysis

# %% [raw]
# The initial idea was that the tropical disease Zika had increased it's infection area because the temperatures of the countries adjacent to the tropical zone had expanded.
#
# We analyzed the United States, choosing states California, Oregon, and Washington. We extracted the historical weather data for three years and the Zika infection rates for the same time period.
#
# The 'cleaning' process involved :
# -ensuring all the states were present
# -all the counts of the infections were populated
# -all the temperatures were present for the Max, Min and Average for the entire year period
# -provide the proper headers
# -adding the year data points
# -adding the state data points
# -grouped the temperatures to generate the mean values for the database
# -extracted the specific data for the infections count
# -create a common index for both
# -concatenated the dataframes
#
# The conclusion is not definitive because the time frame was too small and the infections count spikes and returns to a base line value. The question was not answered because the data set was not large enough and the time frame was not large enough to measure a geographical event like climate change. More data points would be needed to generate a better conclusion.
